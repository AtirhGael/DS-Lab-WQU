# %%
import requests
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"
data = requests.get(standings_url)
from bs4 import BeautifulSoup

# %%
soup = BeautifulSoup(data.text)
standings_table = soup.select('table.stats_table')[0]
links = standings_table.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if '/squads/' in l]

# %%
team_urls = [f"https://fbref.com{l}" for l in links] #adding usl to team string
team_urls # returns absolute links
# Out:
# ['https://fbref.com/en/squads/b8fd03ef/Manchester-City-Stats',
#  'https://fbref.com/en/squads/822bd0ba/Liverpool-Stats',
#  'https://fbref.com/en/squads/18bb7c10/Arsenal-Stats',
#  'https://fbref.com/en/squads/8602292d/Aston-Villa-Stats',
#  'https://fbref.com/en/squads/cff3d9bb/Chelsea-Stats',
#  'https://fbref.com/en/squads/d07537b9/Brighton-and-Hove-Albion-Stats',
#  'https://fbref.com/en/squads/e4a775cb/Nottingham-Forest-Stats',
#  'https://fbref.com/en/squads/361ca564/Tottenham-Hotspur-Stats',
#  'https://fbref.com/en/squads/cd051869/Brentford-Stats',
#  'https://fbref.com/en/squads/fd962109/Fulham-Stats',
#  'https://fbref.com/en/squads/4ba7cbea/Bournemouth-Stats',
#  'https://fbref.com/en/squads/b2b47a98/Newcastle-United-Stats',
#  'https://fbref.com/en/squads/7c21e445/West-Ham-United-Stats',
#  'https://fbref.com/en/squads/19538871/Manchester-United-Stats',
#  'https://fbref.com/en/squads/a2d435b3/Leicester-City-Stats',
#  'https://fbref.com/en/squads/d3fd31cc/Everton-Stats',
#  'https://fbref.com/en/squads/47c64c55/Crystal-Palace-Stats',
#  'https://fbref.com/en/squads/b74092de/Ipswich-Town-Stats',
#  'https://fbref.com/en/squads/8cec06e1/Wolverhampton-Wanderers-Stats',
#  'https://fbref.com/en/squads/33c895d4/Southampton-Stats']

# %%
# extracting match stats using pandas
import pandas as pd
from io import StringIO

team_url = team_urls[0]
data = requests.get(team_url)
html_data = data.text
matches = pd.read_html(data.text, match = 'Scores & Fixtures')
matches[0]
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17780\1886913858.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   matches = pd.read_html(data.text, match = 'Scores & Fixtures')
#           Date   Time                 Comp                Round  Day Venue  \
# 0   2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat  Home
# 1   2024-08-18  16:30       Premier League          Matchweek 1  Sun  Away
# 2   2024-08-24  15:00       Premier League          Matchweek 2  Sat  Home
# 3   2024-08-31  17:30       Premier League          Matchweek 3  Sat  Away
# 4   2024-09-14  15:00       Premier League          Matchweek 4  Sat  Home
# 5   2024-09-18  20:00         Champions Lg         League phase  Wed  Home
# 6   2024-09-22  16:30       Premier League          Matchweek 5  Sun  Home
# 7   2024-09-24  19:45              EFL Cup          Third round  Tue  Home
# 8   2024-09-28  12:30       Premier League          Matchweek 6  Sat  Away
# 9   2024-10-01  21:00         Champions Lg         League phase  Tue  Away
# 10  2024-10-05  15:00       Premier League          Matchweek 7  Sat  Home
# 11  2024-10-20  14:00       Premier League          Matchweek 8  Sun  Away
# 12  2024-10-23  20:00         Champions Lg         League phase  Wed  Home
# 13  2024-10-26  15:00       Premier League          Matchweek 9  Sat  Home
# 14  2024-10-30  20:15              EFL Cup         Fourth round  Wed  Away
# 15  2024-11-02  15:00       Premier League         Matchweek 10  Sat  Away
# 16  2024-11-05  20:00         Champions Lg         League phase  Tue  Away
# 17  2024-11-09  17:30       Premier League         Matchweek 11  Sat  Away
# 18  2024-11-23  17:30       Premier League         Matchweek 12  Sat  Home
# 19  2024-11-26  20:00         Champions Lg         League phase  Tue  Home
# 20  2024-12-01  16:00       Premier League         Matchweek 13  Sun  Away
# 21  2024-12-04  19:30       Premier League         Matchweek 14  Wed  Home
# 22  2024-12-07  15:00       Premier League         Matchweek 15  Sat  Away
# 23  2024-12-11  21:00         Champions Lg         League phase  Wed  Away
# 24  2024-12-15  16:30       Premier League         Matchweek 16  Sun  Home
# 25  2024-12-21  12:30       Premier League         Matchweek 17  Sat  Away
# 26  2024-12-26  12:30       Premier League         Matchweek 18  Thu  Home
# 27  2024-12-29  14:30       Premier League         Matchweek 19  Sun  Away
# 28  2025-01-04  15:00       Premier League         Matchweek 20  Sat  Home
# 29  2025-01-14  19:30       Premier League         Matchweek 21  Tue  Away
# 30  2025-01-19  16:30       Premier League         Matchweek 22  Sun  Away
# 31  2025-01-22  21:00         Champions Lg         League phase  Wed  Away
# 32  2025-01-25  17:30       Premier League         Matchweek 23  Sat  Home
# 33  2025-01-29  20:00         Champions Lg         League phase  Wed  Home
# 34  2025-02-01  15:00       Premier League         Matchweek 24  Sat  Away
# 35  2025-02-15  15:00       Premier League         Matchweek 25  Sat  Home
# 36  2025-02-22  15:00       Premier League         Matchweek 26  Sat  Home
# 37  2025-02-25  19:45       Premier League         Matchweek 27  Tue  Away
# 38  2025-03-08  15:00       Premier League         Matchweek 28  Sat  Away
# 39  2025-03-15  15:00       Premier League         Matchweek 29  Sat  Home
# 40  2025-04-02  19:45       Premier League         Matchweek 30  Wed  Home
# 41  2025-04-05  15:00       Premier League         Matchweek 31  Sat  Away
# 42  2025-04-12  15:00       Premier League         Matchweek 32  Sat  Home
# 43  2025-04-19  15:00       Premier League         Matchweek 33  Sat  Away
# 44  2025-04-26  15:00       Premier League         Matchweek 34  Sat  Home
# 45  2025-05-03  15:00       Premier League         Matchweek 35  Sat  Home
# 46  2025-05-10  15:00       Premier League         Matchweek 36  Sat  Away
# 47  2025-05-18  15:00       Premier League         Matchweek 37  Sun  Home
# 48  2025-05-25  16:00       Premier League         Matchweek 38  Sun  Away
#
#    Result     GF     GA              Opponent   xG  xGA  Poss  Attendance  \
# 0       D  1 (7)  1 (6)        Manchester Utd  NaN  NaN  56.0     78146.0
# 1       W      2      0               Chelsea  0.8  1.0  52.0     39818.0
# 2       W      4      1          Ipswich Town  3.3  0.3  75.0     53147.0
# 3       W      3      1              West Ham  3.0  0.7  67.0     62469.0
# 4       W      2      1             Brentford  2.1  1.0  54.0     52148.0
# 5       D      0      0              it Inter  2.3  0.7  60.0     50922.0
# 6       D      2      2               Arsenal  2.1  0.7  77.0     52846.0
# 7       W      2      1               Watford  NaN  NaN  72.0     40584.0
# 8       D      1      1         Newcastle Utd  0.9  1.6  62.0     52248.0
# 9       W      4      0  sk Slovan Bratislava  3.7  0.1  75.0     22500.0
# 10      W      3      2                Fulham  1.6  2.6  58.0     53017.0
# 11      W      2      1                Wolves  1.6  0.8  77.0     31319.0
# 12      W      5      0      cz Sparta Prague  2.9  0.2  79.0     50116.0
# 13      W      1      0           Southampton  2.9  0.2  57.0         NaN
# 14      L      1      2             Tottenham  NaN  NaN  68.0     60797.0
# 15    NaN    NaN    NaN           Bournemouth  NaN  NaN   NaN         NaN
# 16    NaN    NaN    NaN        pt Sporting CP  NaN  NaN   NaN         NaN
# 17    NaN    NaN    NaN              Brighton  NaN  NaN   NaN         NaN
# 18    NaN    NaN    NaN             Tottenham  NaN  NaN   NaN         NaN
# 19    NaN    NaN    NaN          nl Feyenoord  NaN  NaN   NaN         NaN
# 20    NaN    NaN    NaN             Liverpool  NaN  NaN   NaN         NaN
# 21    NaN    NaN    NaN       Nott'ham Forest  NaN  NaN   NaN         NaN
# 22    NaN    NaN    NaN        Crystal Palace  NaN  NaN   NaN         NaN
# 23    NaN    NaN    NaN           it Juventus  NaN  NaN   NaN         NaN
# 24    NaN    NaN    NaN        Manchester Utd  NaN  NaN   NaN         NaN
# 25    NaN    NaN    NaN           Aston Villa  NaN  NaN   NaN         NaN
# 26    NaN    NaN    NaN               Everton  NaN  NaN   NaN         NaN
# 27    NaN    NaN    NaN        Leicester City  NaN  NaN   NaN         NaN
# 28    NaN    NaN    NaN              West Ham  NaN  NaN   NaN         NaN
# 29    NaN    NaN    NaN             Brentford  NaN  NaN   NaN         NaN
# 30    NaN    NaN    NaN          Ipswich Town  NaN  NaN   NaN         NaN
# 31    NaN    NaN    NaN          fr Paris S-G  NaN  NaN   NaN         NaN
# 32    NaN    NaN    NaN               Chelsea  NaN  NaN   NaN         NaN
# 33    NaN    NaN    NaN        be Club Brugge  NaN  NaN   NaN         NaN
# 34    NaN    NaN    NaN               Arsenal  NaN  NaN   NaN         NaN
# 35    NaN    NaN    NaN         Newcastle Utd  NaN  NaN   NaN         NaN
# 36    NaN    NaN    NaN             Liverpool  NaN  NaN   NaN         NaN
# 37    NaN    NaN    NaN             Tottenham  NaN  NaN   NaN         NaN
# 38    NaN    NaN    NaN       Nott'ham Forest  NaN  NaN   NaN         NaN
# 39    NaN    NaN    NaN              Brighton  NaN  NaN   NaN         NaN
# 40    NaN    NaN    NaN        Leicester City  NaN  NaN   NaN         NaN
# 41    NaN    NaN    NaN        Manchester Utd  NaN  NaN   NaN         NaN
# 42    NaN    NaN    NaN        Crystal Palace  NaN  NaN   NaN         NaN
# 43    NaN    NaN    NaN               Everton  NaN  NaN   NaN         NaN
# 44    NaN    NaN    NaN           Aston Villa  NaN  NaN   NaN         NaN
# 45    NaN    NaN    NaN                Wolves  NaN  NaN   NaN         NaN
# 46    NaN    NaN    NaN           Southampton  NaN  NaN   NaN         NaN
# 47    NaN    NaN    NaN           Bournemouth  NaN  NaN   NaN         NaN
# 48    NaN    NaN    NaN                Fulham  NaN  NaN   NaN         NaN
#
#             Captain Formation Opp Formation           Referee  Match Report  \
# 0        Rúben Dias     4-3-3       4-2-3-1    Jarred Gillett  Match Report
# 1   Kevin De Bruyne   3-2-4-1       4-2-3-1    Anthony Taylor  Match Report
# 2   Kevin De Bruyne   3-2-4-1         5-4-1    Samuel Allison  Match Report
# 3   Kevin De Bruyne   3-2-4-1       4-2-3-1    Michael Oliver  Match Report
# 4       Kyle Walker   4-2-3-1         5-3-2       Darren Bond  Match Report
# 5   Kevin De Bruyne   3-2-4-1         3-5-2      Glenn Nyberg  Match Report
# 6       Kyle Walker     4-3-3         4-4-2    Michael Oliver  Match Report
# 7       Kyle Walker   3-2-4-1         5-3-2        David Webb  Match Report
# 8       Kyle Walker   4-2-3-1         4-3-3    Jarred Gillett  Match Report
# 9    İlkay Gündoğan   4-2-3-1       4-2-3-1      Davide Massa  Match Report
# 10       Rúben Dias   4-1-4-1         5-4-1      Peter Bankes  Match Report
# 11       Rúben Dias   4-1-4-1         3-5-2    Chris Kavanagh  Match Report
# 12   Bernardo Silva   4-1-4-1         3-4-3  Maurizio Mariani  Match Report
# 13       Rúben Dias   4-1-4-1         5-4-1   Tony Harrington  Match Report
# 14       Rúben Dias   4-1-4-1         4-3-3      Robert Jones  Match Report
# 15              NaN       NaN           NaN               NaN  Head-to-Head
# 16              NaN       NaN           NaN               NaN  Head-to-Head
# 17              NaN       NaN           NaN               NaN  Head-to-Head
# 18              NaN       NaN           NaN               NaN  Head-to-Head
# 19              NaN       NaN           NaN               NaN  Head-to-Head
# 20              NaN       NaN           NaN               NaN  Head-to-Head
# 21              NaN       NaN           NaN               NaN  Head-to-Head
# 22              NaN       NaN           NaN               NaN  Head-to-Head
# 23              NaN       NaN           NaN               NaN  Head-to-Head
# 24              NaN       NaN           NaN               NaN  Head-to-Head
# 25              NaN       NaN           NaN               NaN  Head-to-Head
# 26              NaN       NaN           NaN               NaN  Head-to-Head
# 27              NaN       NaN           NaN               NaN  Head-to-Head
# 28              NaN       NaN           NaN               NaN  Head-to-Head
# 29              NaN       NaN           NaN               NaN  Head-to-Head
# 30              NaN       NaN           NaN               NaN  Head-to-Head
# 31              NaN       NaN           NaN               NaN  Head-to-Head
# 32              NaN       NaN           NaN               NaN  Head-to-Head
# 33              NaN       NaN           NaN               NaN  Head-to-Head
# 34              NaN       NaN           NaN               NaN  Head-to-Head
# 35              NaN       NaN           NaN               NaN  Head-to-Head
# 36              NaN       NaN           NaN               NaN  Head-to-Head
# 37              NaN       NaN           NaN               NaN  Head-to-Head
# 38              NaN       NaN           NaN               NaN  Head-to-Head
# 39              NaN       NaN           NaN               NaN  Head-to-Head
# 40              NaN       NaN           NaN               NaN  Head-to-Head
# 41              NaN       NaN           NaN               NaN  Head-to-Head
# 42              NaN       NaN           NaN               NaN  Head-to-Head
# 43              NaN       NaN           NaN               NaN  Head-to-Head
# 44              NaN       NaN           NaN               NaN  Head-to-Head
# 45              NaN       NaN           NaN               NaN  Head-to-Head
# 46              NaN       NaN           NaN               NaN  Head-to-Head
# 47              NaN       NaN           NaN               NaN  Head-to-Head
# 48              NaN       NaN           NaN               NaN  Head-to-Head
#
#                                                 Notes
# 0   Manchester City won on penalty kicks following...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN

# %%
soup = BeautifulSoup(data.text)
links = soup.find_all('a')
links = [l.get("href") for l in links]
links = [l for l in links if l and 'all_comps/shooting/' in l] #looking for all links that contains "all_comps/shooting/"
links
# Out:
# ['/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions',
#  '/en/squads/b8fd03ef/2024-2025/matchlogs/all_comps/shooting/Manchester-City-Match-Logs-All-Competitions']

# %%
data = requests.get(f"https://fbref.com{links[0]}")
shooting = pd.read_html(data.text, match="Shooting")[0]
shooting.head() # first 5 elements in the shooting table
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_17780\3638467348.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   shooting = pd.read_html(data.text, match="Shooting")[0]
#   For Manchester City                                                        \
#                  Date   Time                 Comp                Round  Day
# 0          2024-08-10  15:00  FA Community Shield  FA Community Shield  Sat
# 1          2024-08-18  16:30       Premier League          Matchweek 1  Sun
# 2          2024-08-24  15:00       Premier League          Matchweek 2  Sat
# 3          2024-08-31  17:30       Premier League          Matchweek 3  Sat
# 4          2024-09-14  15:00       Premier League          Matchweek 4  Sat
#
#                                               ... Standard                \
#   Venue Result     GF     GA        Opponent  ...     Dist   FK PK PKatt
# 0  Home      D  1 (7)  1 (6)  Manchester Utd  ...      NaN  NaN  0     0
# 1  Away      W      2      0         Chelsea  ...     19.1  0.0  0     0
# 2  Home      W      4      1    Ipswich Town  ...     17.8  1.0  1     1
# 3  Away      W      3      1        West Ham  ...     15.0  1.0  0     0
# 4  Home      W      2      1       Brentford  ...     17.2  0.0  0     0
#
#   Expected                           Unnamed: 25_level_0
#         xG npxG npxG/Sh G-xG np:G-xG        Match Report
# 0      NaN  NaN     NaN  NaN     NaN        Match Report
# 1      0.8  0.8    0.07  1.2     1.2        Match Report
# 2      3.3  2.6    0.20  0.7     0.4        Match Report
# 3      3.0  3.0    0.13  0.0     0.0        Match Report
# 4      2.1  2.1    0.12 -0.1    -0.1        Match Report
#
# [5 rows x 26 columns]

# %%
#merging all the dataframes together 
# shooting.columns = shooting.columns.droplevel()
team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
team_data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 3
#       1 #merging all the dataframes together
#       2 # shooting.columns = shooting.columns.droplevel()
# ----> 3 team_data = matches[0].merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
#       4 team_data.head()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4096, in DataFrame.__getitem__(self, key)
#    4094     if is_iterator(key):
#    4095         key = list(key)
# -> 4096     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4098 # take() does not accept boolean indexers
#    4099 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2763, in MultiIndex._get_indexer_strict(self, key, axis_name)
#    2760 if len(keyarr) and not isinstance(keyarr[0], tuple):
#    2761     indexer = self._get_indexer_level_0(keyarr)
# -> 2763     self._raise_if_missing(key, indexer, axis_name)
#    2764     return self[indexer], indexer
#    2766 return super()._get_indexer_strict(key, axis_name)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\multi.py:2781, in MultiIndex._raise_if_missing(self, key, indexer, axis_name)
#    2779 cmask = check == -1
#    2780 if cmask.any():
# -> 2781     raise KeyError(f"{keyarr[cmask]} not in index")
#    2782 # We get here when levels still contain values which are not
#    2783 # actually in Index anymore
#    2784 raise KeyError(f"{keyarr} not in index")
#
# KeyError: "['Date' 'Sh' 'SoT' 'Dist' 'FK' 'PK' 'PKatt'] not in index"

# %%
years = list(range(2024, 2021, -1))
all_matches = []

# %%
standings_url = "https://fbref.com/en/comps/9/Premier-League-Stats"

# %%
import time
for year in years:
    data = requests.get(standings_url)
    soup = BeautifulSoup(data.text)
    standings_table = soup.select('table.stats_table')[0]

    links = [l.get("href") for l in standings_table.find_all('a')]
    links = [l for l in links if '/squads/' in l]
    team_urls = [f"https://fbref.com{l}" for l in links]
    
    previous_season = soup.select("a.prev")[0].get("href")
    standings_url = f"https://fbref.com{previous_season}"
    
    for team_url in team_urls:
        team_name = team_url.split("/")[-1].replace("-Stats", "").replace("-", " ")
        data = requests.get(team_url)
        matches = pd.read_html(data.text, match="Scores & Fixtures")[0]
        soup = BeautifulSoup(data.text)
        links = [l.get("href") for l in soup.find_all('a')]
        links = [l for l in links if l and 'all_comps/shooting/' in l]
        data = requests.get(f"https://fbref.com{links[0]}")
        shooting = pd.read_html(data.text, match="Shooting")[0]
        shooting.columns = shooting.columns.droplevel()
        try:
            team_data = matches.merge(shooting[["Date", "Sh", "SoT", "Dist", "FK", "PK", "PKatt"]], on="Date")
        except ValueError:
            continue
        team_data = team_data[team_data["Comp"] == "Premier League"]
        
        team_data["Season"] = year
        team_data["Team"] = team_name
        all_matches.append(team_data)
        time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[18], line 5
#       3 data = requests.get(standings_url)
#       4 soup = BeautifulSoup(data.text)
# ----> 5 standings_table = soup.select('table.stats_table')[0]
#       7 links = [l.get("href") for l in standings_table.find_all('a')]
#       8 links = [l for l in links if '/squads/' in l]
#
# IndexError: list index out of range

# %%
len(all_matches)
# Out:
# 16

# %%
match_df = pd.concat(all_matches)

# %%
match_df.columns = [c.lower() for c in match_df.columns]

# %%
match_df
# Out:
#           date   time            comp        round  day venue result gf ga  \
# 1   2024-08-18  16:30  Premier League  Matchweek 1  Sun  Away      W  2  0
# 2   2024-08-24  15:00  Premier League  Matchweek 2  Sat  Home      W  4  1
# 3   2024-08-31  17:30  Premier League  Matchweek 3  Sat  Away      W  3  1
# 4   2024-09-14  15:00  Premier League  Matchweek 4  Sat  Home      W  2  1
# 6   2024-09-22  16:30  Premier League  Matchweek 5  Sun  Home      D  2  2
# ..         ...    ...             ...          ...  ...   ...    ... .. ..
# 6   2024-09-21  15:00  Premier League  Matchweek 5  Sat  Away      D  1  1
# 7   2024-09-28  15:00  Premier League  Matchweek 6  Sat  Home      W  2  1
# 8   2024-10-05  17:30  Premier League  Matchweek 7  Sat  Home      D  0  0
# 9   2024-10-19  15:00  Premier League  Matchweek 8  Sat  Away      W  2  0
# 10  2024-10-26  17:30  Premier League  Matchweek 9  Sat  Home      D  1  1
#
#           opponent  ...  match report  notes  sh  sot  dist   fk pk pkatt  \
# 1          Chelsea  ...  Match Report    NaN  11    5  19.1  0.0  0     0
# 2     Ipswich Town  ...  Match Report    NaN  13    4  17.8  1.0  1     1
# 3         West Ham  ...  Match Report    NaN  23    8  15.0  1.0  0     0
# 4        Brentford  ...  Match Report    NaN  18    7  17.2  0.0  0     0
# 6          Arsenal  ...  Match Report    NaN  33   11  20.2  1.0  0     0
# ..             ...  ...           ...    ...  ..  ...   ...  ... ..   ...
# 6   Leicester City  ...  Match Report    NaN  17    5  17.7  1.0  0     0
# 7   Crystal Palace  ...  Match Report    NaN   8    2  15.3  0.0  0     0
# 8    Newcastle Utd  ...  Match Report    NaN   8    2  24.3  1.0  0     0
# 9     Ipswich Town  ...  Match Report    NaN  11    8  16.4  1.0  0     0
# 10          Fulham  ...  Match Report    NaN  10    5  14.3  0.0  0     0
#
#    season             team
# 1    2024  Manchester City
# 2    2024  Manchester City
# 3    2024  Manchester City
# 4    2024  Manchester City
# 6    2024  Manchester City
# ..    ...              ...
# 6    2024          Everton
# 7    2024          Everton
# 8    2024          Everton
# 9    2024          Everton
# 10   2024          Everton
#
# [144 rows x 28 columns]

# %%
match_df.to_csv("matches.csv")
